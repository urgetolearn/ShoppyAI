# %%
# !git clone https://github.com/fashn-AI/fashn-vton-1.5.git
# %cd fashn-vton-1.5
# Out:
# Cloning into 'fashn-vton-1.5'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 92 (delta 20), reused 13 (delta 13), pack-reused 67 (from 1)
# Receiving objects: 100% (92/92), 334.44 KiB | 11.94 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/fashn-vton-1.5

# %%
# !ls
# Out:
# examples  LICENSE  pyproject.toml  README.md  scripts  src  tests

# %%
# !cat pyproject.toml
# Out:
# [build-system]
# requires = ["setuptools>=61.0", "wheel"]
# build-backend = "setuptools.build_meta"
#
# [project]
# name = "fashn-vton"
# version = "1.5.0"
# description = "FASHN VTON v1.5"
# license = {text = "Apache-2.0"}
# authors = [
#     {name = "FASHN AI", email = "dan@fashn.ai"}
# ]
# keywords = ["virtual try-on", "diffusion models", "fashion", "AI", "deep learning"]
# classifiers = [
#     "Development Status :: 4 - Beta",
#     "Intended Audience :: Developers",
#     "Intended Audience :: Science/Research",
#     "License :: OSI Approved :: Apache Software License",
#     "Operating System :: OS Independent",
#     "Programming Language :: Python :: 3",
#     "Programming Language :: Python :: 3.10",
#     "Programming Language :: Python :: 3.11",
#     "Programming Language :: Python :: 3.12",
#     "Topic :: Scientific/Engineering :: Artificial Intelligence",
#     "Topic :: Scientific/Engineering :: Image Processing",
# ]
# requires-python = ">=3.10"
# dependencies = [
# ...

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/fashn-vton-1.5
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 MB 5.8 MB/s eta 0:00:00
# ...
#   Building editable for fashn-vton (pyproject.toml) ... done
#   Created wheel for fashn-vton: filename=fashn_vton-1.5.0-0.editable-py3-none-any.whl size=5770 sha256=945295bd279a2bf0def1ede770ce7d27980962e2f2a1777f24ae363f2e175c99
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tzf9ntql/wheels/83/85/d4/003a2789df48fea4fd69c5093b73b4495d75e045a364d41756
# Successfully built fashn-vton
# ...

# %%
# !python scripts/download_weights.py --weights-dir ./weights
# Out:
# ...
#
# ...
#
# model.safetensors: downloading bytes:   0% 0.00/1.94G [00:00<?, ?B/s]
# model.safetensors: downloading bytes:   1% 24.0M/1.94G [00:01<01:22, 23.2MB/s, 1.26MB/s  ]
# model.safetensors: reconstructing file:   1% 13.2M/1.94G [00:01<03:08, 10.3MB/s,  142kB/s  ]
# model.safetensors: downloading bytes:   2% 36.2M/1.94G [00:01<00:58, 32.8MB/s, 2.45MB/s  ]
# model.safetensors: downloading bytes:   2% 43.8M/1.94G [00:01<00:55, 34.2MB/s, 3.61MB/s  ]
# model.safetensors: downloading bytes:   4% 68.5M/1.94G [00:02<00:35, 53.4MB/s, 5.48MB/s  ]
# model.safetensors: downloading bytes:   5% 97.2M/1.94G [00:02<00:33, 54.8MB/s, 8.31MB/s  ]
# model.safetensors: downloading bytes:   7% 137M/1.94G [00:03<00:25, 71.9MB/s, 11.0MB/s  ]
# model.safetensors: downloading bytes:   8% 148M/1.94G [00:03<00:28, 63.3MB/s, 12.0MB/s  ]
# model.safetensors: downloading bytes:   8% 156M/1.94G [00:03<00:27, 66.0MB/s, 12.7MB/s  ]
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_4289/1655152573.py in <cell line: 0>()
#       1 import torch
#       2 print(torch.cuda.is_available())
# ----> 3 print(torch.cuda.get_device_name(0))
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in get_device_name(device)
#     651         str: the name of the device
#     652     """
# --> 653     return get_device_properties(device).name
#     654
#     655
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py in get_device_properties(device)
#     684         _CudaDeviceProperties: the properties of the device
#     685     """
# --> 686     _lazy_init()  # will define _get_device_properties
#     687     device = _get_device_index(device, optional=True)
#     688     if device < 0 or device >= device_count():
#
# ...

# %%
# !nvidia-smi
# Out:
# Sun Jul 19 17:28:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.11.0+cu128
# 12.8

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
from PIL import Image
from fashn_vton import TryOnPipeline

pipeline = TryOnPipeline(weights_dir="./weights")

person = Image.open("person.jpeg")
garment = Image.open("garment.jpg")

result = pipeline(
    person,
    garment,
    category="tops"
)

result.images[0].save("output.png")
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1159/36826255.py in <cell line: 0>()
#       1 from PIL import Image
# ----> 2 from fashn_vton import TryOnPipeline
#       3
#       4 pipeline = TryOnPipeline(weights_dir="./weights")
#       5
#
# ModuleNotFoundError: No module named 'fashn_vton'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
# !find /content -maxdepth 2 -type d -name "fashn-vton-1.5"

# %%
# %cd /content/fashn-vton-1.5
# !pip install -e .
# Out:
# [Errno 2] No such file or directory: '/content/fashn-vton-1.5'
# /content
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# %cd /content
# !git clone https://github.com/fashn-AI/fashn-vton-1.5.git
# %cd /content/fashn-vton-1.5
# Out:
# /content
# Cloning into 'fashn-vton-1.5'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 92 (delta 20), reused 13 (delta 13), pack-reused 67 (from 1)
# Receiving objects: 100% (92/92), 334.44 KiB | 25.73 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/fashn-vton-1.5

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/fashn-vton-1.5
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 MB 5.4 MB/s eta 0:00:00
# ...
#   Building editable for fashn-vton (pyproject.toml) ... done
#   Created wheel for fashn-vton: filename=fashn_vton-1.5.0-0.editable-py3-none-any.whl size=5770 sha256=9b0353abec230f05b37b226d3112aa5413a2bf7f20dda28d59a696e6591058f2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ulshwu9b/wheels/83/85/d4/003a2789df48fea4fd69c5093b73b4495d75e045a364d41756
# Successfully built fashn-vton
# ...

# %%
# !python scripts/download_weights.py --weights-dir ./weights
# Out:
# ...
#
# ...
#
# model.safetensors: downloading bytes:   0% 1.84M/1.94G [00:02<43:55, 737kB/s]
# model.safetensors: downloading bytes:   1% 18.2M/1.94G [00:02<03:21, 9.58MB/s,  175kB/s  ]
# model.safetensors: downloading bytes:  11% 206M/1.94G [00:04<00:23, 74.1MB/s, 16.1MB/s  ]
# model.safetensors: downloading bytes:  11% 217M/1.94G [00:04<00:28, 59.7MB/s, 17.6MB/s  ]
# model.safetensors: downloading bytes:  12% 225M/1.94G [00:04<00:27, 63.5MB/s, 17.8MB/s  ]
# model.safetensors: downloading bytes:  12% 237M/1.94G [00:05<00:27, 61.1MB/s, 18.7MB/s  ]
# model.safetensors: downloading bytes:  14% 274M/1.94G [00:05<00:17, 96.7MB/s, 20.5MB/s  ]
# model.safetensors: downloading bytes:  16% 318M/1.94G [00:05<00:15, 104MB/s, 24.0MB/s  ]
# model.safetensors: downloading bytes:  17% 333M/1.94G [00:06<00:17, 92.6MB/s, 25.2MB/s  ]
# model.safetensors: downloading bytes:  19% 369M/1.94G [00:06<00:17, 89.4MB/s, 27.7MB/s  ]
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
from PIL import Image
from fashn_vton import TryOnPipeline

pipeline = TryOnPipeline(weights_dir="./weights")

person = Image.open("person.jpeg")
garment = Image.open("garment.png")

result = pipeline(person, garment, category="tops")

result.images[0].save("output.png")

print("Done!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1159/2074289056.py in <cell line: 0>()
#       1 from PIL import Image
# ----> 2 from fashn_vton import TryOnPipeline
#       3
#       4 pipeline = TryOnPipeline(weights_dir="./weights")
#       5
#
# ModuleNotFoundError: No module named 'fashn_vton'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !pip show fashn-vton
# Out:
# Name: fashn-vton
# Version: 1.5.0
# Summary: FASHN VTON v1.5
# Home-page: https://github.com/fashn-AI/fashn-vton-1.5
# Author:
# Author-email: FASHN AI <dan@fashn.ai>
# License: Apache-2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Editable project location: /content/fashn-vton-1.5
# Requires: einops, fashn-human-parser, huggingface_hub, matplotlib, numpy, onnxruntime-gpu, opencv-python, pillow, safetensors, torch, torchvision, tqdm
# Required-by:

# %%
import site
print(site.getsitepackages())
# Out:
# ['/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/lib/python3.12/dist-packages']

# %%
import fashn_vton
print(fashn_vton.__file__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1159/2364265853.py in <cell line: 0>()
# ----> 1 import fashn_vton
#       2 print(fashn_vton.__file__)
#
# ModuleNotFoundError: No module named 'fashn_vton'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %pip install -e /content/fashn-vton-1.5
# Out:
# Obtaining file:///content/fashn-vton-1.5
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for fashn-vton (pyproject.toml) ... done
#   Created wheel for fashn-vton: filename=fashn_vton-1.5.0-0.editable-py3-none-any.whl size=5770 sha256=5bf2b3fab75967c585317b72c1ac75fea106626133d79708512d173c5cd6cc7c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-73mofmjr/wheels/83/85/d4/003a2789df48fea4fd69c5093b73b4495d75e045a364d41756
# Successfully built fashn-vton
# ...
#   Attempting uninstall: fashn-vton
#     Found existing installation: fashn-vton 1.5.0
#     Uninstalling fashn-vton-1.5.0:
#       Successfully uninstalled fashn-vton-1.5.0
# ...

# %%
from fashn_vton import TryOnPipeline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_4617/2141606961.py in <cell line: 0>()
# ----> 1 from fashn_vton import TryOnPipeline
#
# /content/fashn-vton-1.5/src/fashn_vton/__init__.py in <module>
#       3 __version__ = "1.5.0"
#       4
# ----> 5 from .pipeline import PipelineOutput, TryOnPipeline
#       6 from .tryon_mmdit import TryOnModel
#       7
#
# /content/fashn-vton-1.5/src/fashn_vton/pipeline.py in <module>
#      13 from tqdm.auto import tqdm
#      14
# ---> 15 from .dwpose import DWposeDetector, draw_pose
#      16 from .preprocessing import (
#      17     BODY_COVERAGE_TO_FASHN_LABELS,
#
# /content/fashn-vton-1.5/src/fashn_vton/dwpose/__init__.py in <module>
#      14 """
#      15
# ---> 16 from .dwpose import DWposeDetector, draw_pose
#
# /content/fashn-vton-1.5/src/fashn_vton/dwpose/dwpose.py in <module>
#      10     draw_handpose_gray,
# ...

# %%
# !pip show onnxruntime-gpu
# Out:
# Name: onnxruntime-gpu
# Version: 1.27.0
# Summary: ONNX Runtime is a runtime accelerator for Machine Learning models
# Home-page: https://onnxruntime.ai
# Author: Microsoft Corporation
# Author-email: onnxruntime@microsoft.com
# License: MIT License
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: flatbuffers, numpy, packaging, protobuf
# Required-by: fashn-vton

# %%
import torch
print(torch.version.cuda)
# Out:
# 12.8

# %%
# %pip uninstall -y onnxruntime-gpu onnxruntime

# %pip install onnxruntime-gpu==1.22.0
# Out:
# Found existing installation: onnxruntime-gpu 1.27.0
# Uninstalling onnxruntime-gpu-1.27.0:
#   Successfully uninstalled onnxruntime-gpu-1.27.0
# WARNING: Skipping onnxruntime as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.2/283.2 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.5 MB/s eta 0:00:00
# ...

# %%
from fashn_vton import TryOnPipeline

# %%
from PIL import Image
from fashn_vton import TryOnPipeline

pipeline = TryOnPipeline(weights_dir="./weights")
# Out:
# TryOnPipeline - INFO - Using device: cuda
# TryOnPipeline - INFO - Using dtype: torch.bfloat16
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5467/3384938891.py in <cell line: 0>()
#       2 from fashn_vton import TryOnPipeline
#       3
# ----> 4 pipeline = TryOnPipeline(weights_dir="./weights")
#
# /content/fashn-vton-1.5/src/fashn_vton/pipeline.py in __init__(self, weights_dir, device, logger)
#      77
#      78         # Validate weights exist
# ---> 79         self._validate_weights()
#      80
#      81         # Load models
#
# /content/fashn-vton-1.5/src/fashn_vton/pipeline.py in _validate_weights(self)
#     106
#     107         if missing:
# --> 108             raise FileNotFoundError(
#     109                 "Missing model weights:\n"
#     110                 + "\n".join(f"  - {p}" for p in missing)
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !ls -R /content/fashn-vton-1.5/weights
# Out:
# /content/fashn-vton-1.5/weights:
# dwpose	model.safetensors
#
# /content/fashn-vton-1.5/weights/dwpose:
# dw-ll_ucoco_384.onnx  yolox_l.onnx

# %%
# %cd /content/fashn-vton-1.5
# Out:
# /content/fashn-vton-1.5

# %%
import os
print(os.getcwd())
# Out:
# /content/fashn-vton-1.5

# %%
pipeline = TryOnPipeline(weights_dir="./weights")
# Out:
# TryOnPipeline - INFO - Using device: cuda
# TryOnPipeline - INFO - Using dtype: torch.bfloat16
# TryOnPipeline - INFO - Loading TryOnModel from /content/fashn-vton-1.5/weights/model.safetensors
# TryOnPipeline - INFO - TryOnModel loaded
# TryOnPipeline - INFO - Loading DWPose from /content/fashn-vton-1.5/weights/dwpose
# TryOnPipeline - INFO - DWPose loaded
# TryOnPipeline - INFO - Loading FashnHumanParser
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/930 [00:00<?, ?it/s]
# TryOnPipeline - INFO - FashnHumanParser loaded

# %%
from PIL import Image

person = Image.open("/content/person.jpeg").convert("RGB")
garment = Image.open("/content/garment.png").convert("RGB")

result = pipeline(
    person,
    garment,
    category="tops"
)

result.images[0].save("/content/output.png")
result.images[0]
# Out:
# TryOnPipeline - INFO - Running inference with 30 timesteps...
# Sampling:   0%|          | 0/30 [00:00<?, ?it/s]
# TryOnPipeline - INFO - Generated 1 images
# <PIL.Image.Image image mode=RGB size=486x864>
